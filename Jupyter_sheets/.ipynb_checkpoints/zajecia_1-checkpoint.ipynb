# %% [markdown]
# <h1 style="color: darkred">Wprowadzenie do programowania</h1>
# <h2>mgr Jan Kosiński</h2>
# <h3>Zakład Biologii Obliczeniowej<br>Wydział Biologii<br>Uniwersytet im. Adama Mickiewicza w Poznaniu</h3>
# <h3>jankos@amu.edu.pl</h3>

# %% [markdown]
# <h2 style="color: darkgreen">programować</h2>
# <ol>
# <li><b>«pisać programy komputerowe»</b></li>
# <li>«ustawiać, najczęściej automatycznie, parametry pracy jakiegoś urządzenia»</li>
# <li>«układać program jakiegoś działania, jakiejś imprezy itp.»</li>
# </ol>
# <b>język programowania - «system znaków przystosowany do pisania programów dla komputerów cyfrowych»<br></b>
#
# <p style="text-align: right">Słownik Języka Polskiego PWN</p>

# %% [markdown]
# <h2 style="color: darkgreen">program</h2>
# <ol>
# <li>«plan zamierzonych czynności, przedsięwzięć itp.»</li>
# <li>«założenia, postulaty i cele jakiejś działalności»</li>
# <li>«repertuar teatru, opery itp.; też: opis tego repertuaru wydrukowany w formie broszury, ulotki lub w gazecie»</li>
# <li>«broszura zawierająca informacje o danym przedstawieniu, koncercie itp.»</li>
# <li>«szereg elementów spektaklu, występu itp. następujących po sobie w określonej kolejności»</li>
# <li>«audycja radiowa albo telewizyjna; też: spis takich audycji nadawanych w danym dniu lub tygodniu»</li>
# <li>«zestaw audycji radiowych lub telewizyjnych nadawanych przez daną rozgłośnię na stałej częstotliwości»</li>
# <li>«zakres wiedzy objętej nauczaniem szkolnym lub akademickim; też: wykaz przedmiotów objętych takim nauczaniem»</li>
# <li><b>«ciąg instrukcji napisanych w języku zrozumiałym dla komputera»</b></li>
# <ol>
#     <p style="text-align: right">Słownik Języka Polskiego PWN</p>

# %% [markdown]
# <h2 style="color: darkgreen">podsumowanie</h2>
# <p>Programowanie to zapisywanie (przy pomocy wybranego języka programowania) skończonych ciągów instrukcji (algorytmów), mających na celu rozwiązanie konkretnego problemu</p>

# %% [markdown]
# <h2 style="color: darkgreen">algorytm</h2><br>
# «ściśle określony ciąg czynności, których wykonanie prowadzi do rozwiązania jakiegoś zadania»
# <p style="text-align: right">Słownik Języka Polskiego PWN</p>
# <br><b>Przykład - algorytm gotowania ziemniaków: </b>
# <ol>
#     <li>Wyciągnij garnek</li>
#     <li>Wyciągnij ziemniaki</li>
#     <li>Wyciągnij obierak do warzyw</li>
#     <li>Obierz ziemniaki</li>
#     <li>Umyj ziemniaki</li>
#     <li>Wrzuć umyte ziemniaki do garnka</li>
#     <li>Zalej ziemniaki wodą (tak by były dokładnie przykryte)</li>
#     <li>Włącz kuchenkę</li>
#     <li>Postaw garnek z ziemniakami na kuchence</li>
#     <li>Gotuj ziemniaki 30 min</li>
#     <li>Wyłącz kuchenkę</li>
#     <li>Odcedź ziemniaki</li>
#     <li>Wyrzuć ziemniaki na talerz</li>
# </ol>

# %% [markdown]
# <h2 style="color: darkgreen">Kompilatory i Interpretery</h2>
# <p>Język programowania <b>nie jest</b> zrozumiały dla procesora (jednostki odpowiedzialnej za wykonanie kodu programu).</p>
# <p>Procesor "rozumie" jedynie język maszynowy w postaci 0 i 1</p>
# <p>Do tłumaczenia języków programowania na język maszynowy wykorzystujemy interpretery lub kompilatory<p>
# <p>Interpretery tłumaczą i wykonują kod źródłowy linijka po linijce. Kompilatory zaś tłumaczą cały kod źródłowy i zapisują go w postaci pliku wykonywalnego na dysku</p>

# %% [markdown]
# <h2 style="color: darkgreen">Dlaczego Python?</h2>
# <p>Język interpretowany - kod może być łatwo przenoszony pomiędzy różnymi platformami (Linux, Mac, Windows)</p>
# <p>Prosta składnia, duża czytelność kodu</p>
# <p>Język wysokiego poziomu - by wykonać to samo zadanie w większości innych języków musimy zapisać o wiele więcej instrukcji</p>
# <p>Jeden z najpopularniejszych na świecie</p>

# %% [markdown]
# <h2 style="color: darkgreen">Uwaga!</h2>
# <p>Istnieją dwie NIEKOMPATYBILNE ze sobą wersje Pythona - 2 i 3. Wersja 2 wkrótce przestanie być wspierana.</p>

# %% [markdown]
# <h2 style="color: darkgreen">Pobieranie</h2>
# <p>Interesującą nas dystrybucję Pythona możemy pobrać ze strony <i>python.org</i></p>
# <p>Jeżeli używamy systemu Linux lub Mac OS interpreter Pythona powinien być już zainstalowany w naszym systemie</p>

# %% [markdown]
# <h2 style="color: darkgreen">Praca z Pythonem</h2>
# <p>Kod Pythona możemy zapisać do pliku tekstowego z rozszerzeniem <i>.py</i> (możemy do tego użyć notatnika lub bardziej wysublimowanego edytora tekstu -> polecany notepad++, Sublime Tekst lub VisualStudio Code). Taki kod możemy uruchomić przy pomocy linii komend systemu poprzez wywołanie polecenia <i>python nazwa_pliku.py</i>.</p>
# <p>Alternatywnie możemy pracować w trybie <b>interaktywnym</b>, który wywołujemy przy pomocy polecenia <i>python</i></p>
# <p>Możemy także korzystać z programu <b>IDLE</b> -> do pobrania z python.org lub podobnych rozwiązań.</p>
# <p>Na potrzeby tego kursu wykorzystamy rozwiązanie o nazwie <b>Anaconda</b>.</p>

# %% [markdown]
# <h2 style="color: darkgreen">Anaconda</h2>
# <p>Anaconda to najpopularniejsza platforma używana w tzw. Data Science. Posiada bardzo wiele wbudowanych rozszerzeń (bibliotek) dla języków Python i R.</p>
# <p>Przejdź do strony https://www.anaconda.com/distribution/</p>

# %% [markdown]
# ![anaconda1.png](attachment:anaconda1.png)

# %% [markdown]
# <p>Pobierz instalator (Graphical Installer) odpowiedni dla swojego systemu (Python w wersji 3.x). Uruchom instalator, który przeprowadzi Cię przez proces instalacji (w większości przypadków domyślne ustawienie będą ok). Opcjonalnie możemy zainstalować także program VS Code, który jest wspaniałym środowiskiem do pracy z Pythonem (zachęcam do przetestowania).</p>
# <p>W przypadku systemu Windows otwórzmy program <i>Anaconda Prompt</i>. W przypadku systemów Linux lub Mac Os otwórzmy dowolny terminal</p>
# <p>Wpisz komendę <i>jupyter notebook</i> i wciśnij Enter</p>

# %% [markdown]
# <h2 style="color: darkgreen">Jupyter notebook</h2>

# %% [markdown]
# <p>Jupyter notebook składa się z różnego typu komórek, które w zależności od swojego typu mogą zawierać kod (code), tekst sformatowany (markdown) lub niesformatowany (raw).</p>
# <p>Komórki zawierające kod Pythona można uruchamiać i obserwować wyniki w przestrzeni poniżej. Takie podejście pozwala na dokładne opisywanie tworzonego skryptu i pełne zrozumienie wykonywanych operacji.</p>
#
# <ul><b>Przydatne skróty:</b>
#     <li>Shift + Enter - wywołuje kod z danej komórki</li>
#     <li>b - wstawianie pustej komórki poniżej</li>
#     <li>x - usuwanie komórki</li>
#     <li>ii - przerywanie działania danej komórki</li>
# </ul>

# %% [markdown]
# <h2 style="color: darkgreen">print - wypisywanie informacji na standardowe wyjście (stdout)</h2>

# %%
print("Hello world!")
print("Jak", "się", "masz?")
print("Ocena", 5)
print("Dupa")

# %% [markdown]
# <h2 style="color: darkgreen">Python jako kalkulator</h2>

# %%
# informacje umieszczone po znaku '#' są ignorowane -> są to tzw. komentarze ułatwiające zrozumienie i udokumentowanie kodu
print(2 + 2) # dodawanie
print(4 - 2) # odejmowanie
print(5 * 3) # mnożenie
print(6 / 4) # dzielenie
print(6 // 4) # dzielenie całkowitoliczbowe
print(6 % 4) # modulo (reszta z dzielenia)
print(2 ** 2) # potęgowanie

# %% [markdown]
# <p><b>Kolejność działań</b></p>

# %%
print(2 + 2 * 2)
print( (2 + 2) * 2)

# %% [markdown]
# <h2 style="color: darkgreen">Zmienne</h2>
# <p>O zmiennej możemy myśleć jako o nazwie pod którą zapisujemy wartość, która może w przyszłości ulec zmianie.</p>

# %%
x = 5
y = 3
print(x)
print(y)
x = 2
print(x)

# %% [markdown]
# <p>W zależności od rodzaju przechowywanych danych mówimy że zmienna jest określonego typu. W pythonie nie musimy deklarować jakiego typu jest nasza zmienna - python rozpozna typ na podstawie przypisywanych danych.</p>
# <p>Możemy sprawdzić typ zmiennej przy użyciu funkcji type()</p>

# %%
x = 0
print( type(x) ) # liczby całkowite -> typ int (integer)

y = "Hello world!"
print( type(y) ) # typ tekstowy (ciąg znaków) -> typ str (string)

z = True
print( type(z) ) # prawda / fałsz -> typ bool (boolean) -> True lub False

x = 0.5
print( type(x) ) # liczba zmiennoprzecinkowa -> typ float (floating point number)

x = 1e23
print( type(x) ) # notacja naukowa -> typ float (floating point number)

x = None # specjalny typ. Oznacza 'nic'
print( type(x) )

# %%
0.1 + 0.2 # UWAGA! typ float ma określoną precyzję

# %% [markdown]
# <h2 style="color: darkgreen">Konwersja typów</h2>
# <p>Możemy dokonywać konwersji pomiędzy różnym typami zmiennych przy użyciu dedykowanych funkcji.</p>

# %%
zmienna = 0
print( type(zmienna) )
print(zmienna)
zmienna = str(zmienna)
print( type(zmienna) )
print(zmienna)
zmienna = float(zmienna)
print( type(zmienna) )
print(zmienna)

# %% [markdown]
# <p>W zależności od typu danych możemy wykonywać na nich różne operacje.</p>

# %%
"Ala ma " + 5

# %%
"Ala ma " + "kota"

# %%
str(4 + 3)

# %%
"xD " * 5

# %% [markdown]
# <h2 style="color: red">Zadanie 1</h2>
# <p>Przypisz do zmiennej <i>x</i> wartość 10 a do zmiennej <i>y</i> 20. Spróbuj zamienić wartości tych zmiennych tak by zmienna <i>x</i> przechowywała 20 a <i>y</i> 10. Nie przypisuj wartości wprost (<i>y = 10; x = 20</i>).</p>

# %%
x = int(input("Please input first number:\n"))
y = int(input("Please input second number:\n"))
print("x = {}, y = {}".format(x , y))
i1 = x
x = y
y = i1
print("x = {}, y = {}".format(x, y))

# %% [markdown]
# <h2 style="color: darkgreen">Pobieranie inofrmacji z klawiatury</h2>

# %%
imie = input("Podaj swoje imie: ")
print(imie)

# %% [markdown]
# <h2 style="color: darkgreen">Porównywanie wartości</h2>

# %%
10 == 20 # sprawdzamy równość dwóch wartości

# %%
10 == 10

# %%
10 != 10 # sprawdzamy różność dwóch wartości

# %%
20 > 10 # większość

# %%
20 >= 20 # większość lub równość

# %%
20 <= 10 # mniejszość lub równość

# %%
20 < 10 # mniejszość

# %% [markdown]
# <h2 style="color: darkgreen">Instrukcje warunkowe</h2>
# <p>Instrukcje warunkowe pozwalają nam na wykonywanie różnych operacji, zależnie od wyniku innych komend.</p>

# %%
x = 10
if (x == "kotek"): # UWAGA na wcięcia -> charakterystyczne dla języka Python
    x = 20 # do zmiennej x zostanie przypisana wartość 20 jeżeli wcześniej była on równa "kotek"
print(x)

# %%
x = 5
opcja = "nie rób nic"
if (x == 1):
    opcja = "wyłącz"
else: # jeżeli żaden z wcześniejszych warunków nie został spełniony
    opcja = "włącz"

print(opcja)

# %%
if (x == 1):
    opcja = "włącz"
elif (x == 2):
    opcja = "nic nie rób"
elif (x == 3):
    opcja = "zapisz"
elif (x == 4):
    opcja = "otwórz"
else:
    opcja = "wyłącz"

print("Wybrano opcję:", x, opcja)

# %% [markdown]
# <p>Wyrażenia logiczne możemy łączyć ze sobą w bardziej skomplikowane struktury przy użyciu spójników <b>and</b>, <b>or</b> i <b>not</b></p>

# %%
a = 5
x = 1
y = 12
if (a > 1 and a < 12):
    print("something")

# %% [markdown]
# <h2 style="color: red">Zadanie 2</h2>
# <p>Napisz program, który umożliwi wprowadzenie wartości liczbowej z klawiatury. Następnie sprawdzi jej parzystość i wypisze na ekran informację czy jest parzysta czy też nie.</p>

# %%
x = int(input("Please input any number:\n"))
if (x % 2 == 0):
    print("{} is even!".format(x))
else:
    print("{} is odd!".format(x))

# %% [markdown]
# <h2 style="color: red">Zadanie 3</h2>
# <p>Napisz program, który zapyta użytkownika o login i hasło i sprawdzi ich poprawność.</p>

# %%
l = str(input("Please input login:\n"))
p = str(input("Please input password\n"))

login, haslo = "janek", "password1234"

if (l == login and p == haslo):
    print("Login and password are correct.")
else:
    print("Login or password are incorrect. Please try again.")

# %% [markdown]
# <h2 style="color: darkgreen">Listy</h2>
# <p>Listy pozwalają nam na przechowywanie kolekcji elementów (jakichkolwiek -> nawet funkcji) w sposób uporządkowany</p>

# %%
moja_lista = [1,2,3,4,5]
print(moja_lista)
moja_lista.append(6) # dodajemy 6 do moja_lista. Element zawsze zostanie dodany na końcu
print(moja_lista)
moja_lista.pop()
print(moja_lista)

# %% [markdown]
# <p>Możemy odwoływać się do poszczególnych wartości listy przy pomocy tzw. indeksów, które wskazują na poszczególne miejsca. Pierwszy element ma indeks 0.</p>

# %%
print(moja_lista[0])
print(moja_lista[3])

# %%
moja_lista[2] = "apple"
print(moja_lista)

# %% [markdown]
# <p>Możemy sprawdzić jaką długość ma lista -> ile ma elementów</p>

# %%
len(moja_lista)

# %% [markdown]
# <p>Możemy sprawdzić czy dany element znajduje się w liście.</p>

# %%
if 'apple' in moja_lista:
    print("tak jest")

# %%
if 'apple' not in moja_lista:
    print("nie jest")

# %% [markdown]
# <p>Możemy dodać element na konkretnej pozycji używając indeksów (liczymy od 0)</p>

# %%
moja_lista.insert(1, "orange")
print(moja_lista)

# %% [markdown]
# <p>Możemy usunąć element korzystając z jego wartości</p>

# %%
moja_lista.remove("orange")
print(moja_lista) # UWAGA! jeżeli jest więcej elementów o takiej samej wartości to zostanie usunięty tylko pierwszy z nich

# %% [markdown]
# <p>lub indeksu</p>

# %%
moja_lista.pop(2)
print(moja_lista)
# co się stanie po wywołaniu polecenia moja_lista.pop() i moja_lista.clear() ???

# %% [markdown]
# <p>Możemy utworzyć listę kolejnych elementów przy użyciu funkcji range</p>

# %%
cyfry = list( range(0,10) ) # od jakiej wartości do jakiej (z wyłączeniem ostatniej) z krokiem co 1 (domyślnie)
print(cyfry)
parzyste = list( range(2,10,2) ) # od 2 do 10 (z wyłączeniem 10) i krokiem co 2
print(parzyste)
trzy = list(range(1,11,3))
print(trzy)

# %% [markdown]
# <p><b>UWAGA! Kopia listy to ta sama lista!</b></p>

# %%
lista = [1,2,3,4]
kopia_listy = lista
print(lista)
print(kopia_listy)

# %%
kopia_listy.append(5)
print(lista)
print(kopia_listy)

# %%
lista = [1,2,3,4]
kopia_listy = lista.copy() # metoda copy() zwraca rzeczywistą kopię listy
kopia_listy.append(5)
print(lista)
print(kopia_listy)

# %% [markdown]
# <h2 style="color: darkgreen">Operacje arytmetyczne na listach</h2>

# %%
t = ["a", "b", "c", "d"]
t + ["e", "f"]
print(t)

# %%
t = ["a", "b", "c", "d"]
t *= 2
print(t)

# %% [markdown]
# <h2 style="color: darkgreen">Sortowanie</h2>

# %%
lista = ["a", "e", "g", "f", "b", "c", "d", "]", "9"]
lista.sort()
print(lista)

# %%
lista.reverse()
print(lista)

# %% [markdown]
# <h2 style="color: darkgreen">Zaawansowane indeksowanie</h2>

# %%
lista = ["a", "e", "g", "f", "b", "c", "d"]
print(lista[1:])
print(lista[1:4])
print(lista[1:4:2]) # z krokiem co 2
print(lista[:]) # kopia listy -> to samo co metoda copy()
print(lista[-1]) # ostatni element
print(lista[:-1])
print(lista[::-1]) # to samo co metoda reverse()

# %% [markdown]
# <h2 style="color: darkgreen">Ciągi znaków</h2>
# <p>Ciągi znaków zachowują się w wielu przypadkach jak listy</p>

# %%
my_str = "abecadło z pieca spadło"
my_str[2]

# %%
my_str[2] = "a" # ciągi znaków są niemutowalne

# %%
my_str[::-1] # od tyłu

# %%
my_str.count('a') # policzmy wystąpienia litery 'a'

# %%
len(my_str) # jaką ma długość?

# %%
'p' in my_str # czy litera p występuje w naszym ciągu znaków?

# %%
print( my_str )
print( my_str.capitalize() ) # pierwsza litera będzie wielką
print( my_str.upper() ) # wszystkie litery będą wielkie
print( my_str.upper().lower() ) # metody możemy łączyć. W tym przypadku metoda lower() zostanie wykonana na wyniku metody upper()
print( my_str.replace("ab", "--") ) # zamieńmy 'ab' na '--'

# %% [markdown]
# <p>Możemy stworzyć listę z ciągu znaków i odwrotnie</p>

# %%
print(my_str)
lista = my_str.split(" ") # podziel ciąg my_str używając spacji i zapisz poszczególne elementy do lista
print(lista)

# %%
my_str_copy = "-".join(lista) # połączmy elementy z listy lista przy pomocy znaku '-'
print(my_str_copy)

# %% [markdown]
# <p>Inne przydatne metody:</p>

# %%
print( my_str.startswith("ab") ) # czy ciąg znaków my_str zaczyna się od 'ab'
print( my_str.endswith("ab") ) # czy ciąg znaków my_str kończy się 'ab'

# %% [markdown]
# <h2 style="color: darkgreen">Pętle</h2>
# <p>Często chcemy wykonać daną operację kolejno na elementach z danego zbioru (np. listy) lub określoną liczbę razy</p>

# %%
cyfry = list( range(0,10) )
for i in cyfry: # kolejno każdy element z listy cyfry zapisywany jest do zmiennej pomocniczej i
    print(i) # i jest wyświetlany na ekran

# %%
# lub krócej 
for i in range(0,10):
    print(i)

# %% [markdown]
# <p>Możemy też wykonywać operację tak długo aż określony warunek będzie spełniony.</p>

# %%
a = 0
while (a <= 10):
    print(a)
    a = a + 1 # co się stanie jak to usuniemy?

# %% [markdown]
# <h2 style="color: red">Zadanie 4</h2>
# <p>Napisz program, który zapyta użytkownika o login i hasło i sprawdzi ich poprawność. Zestaw nazw uzytkownika i hasel przechowuj w dwóch listach. Jeżeli logowanie się udało poinformuj o tym użytkownika.</p>

# %%
logins = ["dupa", "hanalnakaslo", "123456"]
passwords = ["pupa", "kaslonahanal", "654321"]

user_login = input("Please enter your login\n")
user_password = input("Please enter your password\n")
a = False

for i in range(0,len(login)):
    if login[i] == user_login and password[i] == user_password:
        print("You have been logged in successfully!")
        a = True
if a == False:
    print("Login has failed.")
# Out:
# Please enter your login
# q
# Please enter your password
# q
# Login has failed.

# %% [markdown]
# <h2 style="color: red">Zadanie 5</h2>
# <p>Dodaj do swojego programu menu. Użytkownik będzie miał do wyboru dwie opcje (1 - zaloguj, 2 - zarejestruj się). W przypadku rejestracji nazwa użytkownika i hasło zostaną dodane do odpowiednich list.</p>

# %%
option = input("1 - Log in; 2 - Register: \n")
login = input("Login: ")
password = input("Password: ")

if option == "1":
    a = False
    for i in range(0, len(logins)):
        if logins[i] == login and passwords[i] == password:
            print("Logged in.")
            a = True
    if a == False:
        print("There is no such username.")
elif option == "2":
    logins.append(login)
    passwords.append(password)
# Out:
# 1 - Log in; 2 - Register:
# 2
# Login: q
# Password: q

# %% [markdown]
# <h2 style="color: red">Zadanie 6</h2>
# <p>Dodaj zabezpieczenia. W polu wyboru opcji możliwe powinno być tylko i wyłącznie podanie wartości '1' lub '2'. Loginy nie mogą się powtarzać w tworzonych strukturach danych. Wartości nie mogą być puste.</p>

# %%
while True:
    opcja = input("1 = zaloguj; 2 = zarejestruj")
    if opcja == "1" or opcja == "2":
        break
    print("You can use only 1 or 2")
    
while True:
    login = input("Login: ")
    if len(login) > 0 and login not in logins:
        break
    print("Login nie może być pusty lub używaniy")
    
while True:
    password = input("Password: ")
    if len(password) > 0 and password not in passwords:
        break
    print("Hasło nie może być puste lub wcześniej używane")
# Out:
# 1 = zaloguj; 2 = zarejestruj3
# You can use only 1 or 2
# 1 = zaloguj; 2 = zarejestruj1
